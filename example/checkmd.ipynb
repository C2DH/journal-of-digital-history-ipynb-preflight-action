# %% [markdown]
# # Example to check if the markdown of the Notebook is ok

# %% [markdown]
# ## Introduction

# %% [markdown]
# You cannot put a title in the middle of a Markdown Cell
#
# ## this is not correct

# %%
print("Hello Yaroslav")

# %%
1+1
